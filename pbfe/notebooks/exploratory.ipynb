# %%
import numpy as np
import os 



os.chdir(r"C:\Users\carlo\Desktop\pbfe-deeplearning")
d = np.load("pbfe/data/datasets/pbfe_train.npz", allow_pickle=True)



print(d["X_seq"].shape)
print(d["X_feat"].shape)
print(d["y"].shape)


print(d.files)
# Out:
# (672, 20, 4)
# (672, 11)
# (672,)
# ['X_seq', 'X_feat', 'y']
